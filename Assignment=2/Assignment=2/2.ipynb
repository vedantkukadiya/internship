# %%
num = [140, 1771, 256, 3000, 50000]

for n in num:
    if n % 2 == 0:
        print(n, "Even Number")
    else:
        print(n, "Odd Number")
# Out:
# 140 Even Number
# 1771 Odd Number
# 256 Even Number
# 3000 Even Number
# 50000 Even Number
