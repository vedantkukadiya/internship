# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.plot(df['Month'],df['Costs'] ,color='blue',marker='o',label='Costs',linestyle='--',linewidth=2,markersize=6)
plt.xlabel('Month')
plt.ylabel('Costs')
plt.title('Monthly Costs')
plt.grid(color='black',linestyle='--',linewidth=0.2)
plt.legend(loc='upper right',fontsize=12)
plt.show()
