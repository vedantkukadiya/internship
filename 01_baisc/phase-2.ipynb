# %% [markdown]
# ##sorting

# %%
import numpy as np

# %%
unsorted=np.array([4,6,3,2,8,9,12,67])
print("unsorted array", np.sort(unsorted))
# Out:
# unsorted array [ 2  3  4  6  8  9 12 67]

# %%
twod_unsorted = np.array([[5,6],[12,70],[3,1],[6,1]])
print("2d unsorted array", np.sort(twod_unsorted,axis=0))
# Out:
# 2d unsorted array [[ 3  1]
#  [ 5  1]
#  [ 6  6]
#  [12 70]]
