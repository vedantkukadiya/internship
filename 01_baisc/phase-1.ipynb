# %% [markdown]
# ## Numpy Array

# %%
import numpy as np

# %% [markdown]
# ## Creating Array List

# %%
arr_1d = np.array([1,2,3,4])
print("1D Array : ", arr_1d)

arr_2d = np.array([[1,2,3],[4,5,6]])
print("2D Array : ", arr_2d)
# Out:
# 1D Array :  [1 2 3 4]
# 2D Array :  [[1 2 3]
#  [4 5 6]]

# %% [markdown]
# ## list VS Numpy Array

# %%
plist=[1,2,3,4]
print("Pytho Mul : ", plist*2)

n_list=np.array([1,2,3,4])
print("Numpy Mul : ", n_list*2)
# Out:
# Pytho Mul :  [1, 2, 3, 4, 1, 2, 3, 4]
# Numpy Mul :  [2 4 6 8]

# %%
import time

start = time.time()

np_array = np.arange(1000000)*2
print("\n numpy operation time ",time.time() - start)
# Out:
#  numpy operation time  0.009537220001220703

# %%
start = time.time()
py_array = [i*2 for i in range(1000000)]
print("\n python operation time ", time.time() - start)
# Out:
#  python operation time  0.2480173110961914
